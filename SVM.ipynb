# %%
import cvxpy as cp
import matplotlib.pyplot as plt
import numpy as np

# %%
def svm(X, Y, d):
    constraints = []
    w = cp.Variable(d)
    b = cp.Variable(1)
    for i in range(len(X)):
        constraints.append(Y[i]*(X[i]@w + b) >= 1)
    objective = cp.Minimize(cp.sum_squares(w))
    prob = cp.Problem(objective, constraints)
    result = prob.solve()
    return w.value, b.value

# %%
n, d = 10, 3
X1 = np.array([3, 2, 1]) + 2*np.random.randn(n, d)
X2 = np.array([-1, -2, -2]) + np.random.randn(n, d)
X = np.concatenate((X1, X2))
Y = [1]*n + [-1]*n
w_opt, b_opt = svm(X, Y, d)

# %%
x = np.linspace(-5,5,10)
y = np.linspace(-5,5,10)
X,Y = np.meshgrid(x,y)
Z = -(X*w_opt[0] + Y*w_opt[1] + b_opt)/w_opt[2]

# avec matplotlib: 
#import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D
#fig = plt.figure()
#ax = fig.gca(projection='3d')
#surf = ax.plot_surface(X, Y, Z, alpha = .4)
#ax.scatter(X1[:, 0], X1[:, 1], X1[:, 2])
#ax.scatter(X2[:, 0], X2[:, 1], X2[:, 2])

# %%
import plotly.graph_objects as go

data = [go.Surface(x=X, y=Y, z=Z, colorscale = [[0, "yellow"], [1, "yellow"]], opacity = .5), 
        go.Scatter3d(x=X2[:,0], y=X2[:, 1], z=X2[:, 2], mode='markers'),
        go.Scatter3d(x=X1[:,0], y=X1[:, 1], z=X1[:, 2], mode='markers')]

layout = go.Layout(scene = dict(zaxis = dict(nticks=4, range=[-5,5])),
                   showlegend = False)

fig = go.Figure(data=data, layout=layout)

fig.show()
# Out:
# <div>
#
#
#             <div id="8b34a5b7-dcab-4c94-9002-6a572aeaf27f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b34a5b7-dcab-4c94-9002-6a572aeaf27f")) {
#                     Plotly.newPlot(
#                         '8b34a5b7-dcab-4c94-9002-6a572aeaf27f',
#                         [{"colorscale": [[0, "yellow"], [1, "yellow"]], "opacity": 0.5, "type": "surface", "x": [[-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0], [-5.0, -3.888888888888889, -2.7777777777777777, -1.6666666666666665, -0.5555555555555554, 0.5555555555555554, 1.666666666666667, 2.7777777777777786, 3.8888888888888893, 5.0]], "y": [[-5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5.0, -5.0], [-3.888888888888889, -3.888888888888889, -3.888888888888889, -3.888888888888889, -3.888888888888889, -3.888888888888889, -3.888888888888889, -3.888888888888889, -3.888888888888889, -3.888888888888889], [-2.7777777777777777, -2.7777777777777777, -2.7777777777777777, -2.7777777777777777, -2.7777777777777777, -2.7777777777777777, -2.7777777777777777, -2.7777777777777777, -2.7777777777777777, -2.7777777777777777], [-1.6666666666666665, -1.6666666666666665, -1.6666666666666665, -1.6666666666666665, -1.6666666666666665, -1.6666666666666665, -1.6666666666666665, -1.6666666666666665, -1.6666666666666665, -1.6666666666666665], [-0.5555555555555554, -0.5555555555555554, -0.5555555555555554, -0.5555555555555554, -0.5555555555555554, -0.5555555555555554, -0.5555555555555554, -0.5555555555555554, -0.5555555555555554, -0.5555555555555554], [0.5555555555555554, 0.5555555555555554, 0.5555555555555554, 0.5555555555555554, 0.5555555555555554, 0.5555555555555554, 0.5555555555555554, 0.5555555555555554, 0.5555555555555554, 0.5555555555555554], [1.666666666666667, 1.666666666666667, 1.666666666666667, 1.666666666666667, 1.666666666666667, 1.666666666666667, 1.666666666666667, 1.666666666666667, 1.666666666666667, 1.666666666666667], [2.7777777777777786, 2.7777777777777786, 2.7777777777777786, 2.7777777777777786, 2.7777777777777786, 2.7777777777777786, 2.7777777777777786, 2.7777777777777786, 2.7777777777777786, 2.7777777777777786], [3.8888888888888893, 3.8888888888888893, 3.8888888888888893, 3.8888888888888893, 3.8888888888888893, 3.8888888888888893, 3.8888888888888893, 3.8888888888888893, 3.8888888888888893, 3.8888888888888893], [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0]], "z": [[12.361055405696757, 10.501350692771457, 8.641645979846157, 6.781941266920858, 4.9222365539955595, 3.062531841070261, 1.202827128144961, -0.6568775847803394, -2.516582297705638, -4.376287010630937], [11.254468332360544, 9.394763619435244, 7.5350589065099465, 5.6753541935846465, 3.8156494806593466, 1.955944767734048, 0.09624005480874816, -1.7634646581165523, -3.6231693710 ...
#                         {"scene": {"zaxis": {"nticks": 4, "range": [-5, 5]}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinec
